# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
vertical_margin = 20
horizontal_margin = 100
x_size = 28
y_size = 25
linewidth = 4
src = 'https://gist.githubusercontent.com/borgar/31c1e476b8e92a11d7e9/raw/0fae97dab6830ecee185a63c1cee0008f6778ff6/pulsar.csv'
plot_name='plot.png'

# %%
df = pd.read_csv(src, header=None)
plt.style.use('dark_background')
fig, ax = plt.subplots(figsize=(x_size,y_size))

n_lines = df.shape[0]
x = range(df.shape[1])

for row in df.iterrows():
    line = [max(x row[1].values/3 + (n_lines - row[0]))
    line = line // 1   # integer division
    ax.plot(x, line, lw=linewidth, c='white', alpha=1, zorder=row[0]/n_lines)
    ax.fill_between(x, -5,line,  facecolor='black', zorder=row[0]/n_lines)

ax.set_yticks([])
ax.set_xticks([])
ax.set_xlim(min(x)-horizontal_margin, max(x)+horizontal_margin)
ax.set_ylim(-vertical_margin, df.shape[0] + vertical_margin)
plt.savefig(plot_name)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 9
#       6 x = range(df.shape[1])
#       8 for row in df.iterrows():
# ----> 9     line = max(0.5, row[1].values/3 + (n_lines - row[0]))
#      10     line = line // 1   # integer division
#      11     ax.plot(x, line, lw=linewidth, c='white', alpha=1, zorder=row[0]/n_lines)
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
